# %% [markdown]
# Mainly just worked on adding a proper way of storing your mal credentials

# %% [markdown]
# Found the script mal_token.sh, which relieved a bunch of my doubts in my programming abilities. Shout out to this guy:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I have been trying for 2 hours to try to make a listener in python that will correctly get the response from the nonce request in oAuth. The first thing that I tried was to host an http server via python. This wasn't working, as My Anime List couldn't route back to it, and would only respond to my requests in the browser made by me.\

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [[https://stackoverflow.com/questions/70202080/html-file-in-python-https-server]]

# %% [markdown]
# I was getting nowhere, constantly having to spawn new terminals and installing ncat, nc for windows. It apparently has a bunch of more bells and whistles, but I couldn't get it to respond to the redirect with an acknowledge, so I instead just had to pipe the output into a file. But then the action of constantly checking a file for new lines reminded me of a project that I worked on for the minecraft logs. They were always being added to, and there was one language with native async support that would be able to help. Javascript. So I got to thinking, is there any better way of doing this, so that the browser tab can be closed immediately?

# %% [markdown]
# And that's when I thought of Express JS. It was everything that I wanted. It would respond with nothing and you could tell that the back end had done something.

# %% [markdown]
# SO TURNS OUT I WAS JUST LISTENING ON THE WRONG PORT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can't seem to get rid of these whitespaces, instead we're not passing the lizard test

# %% [markdown]
# It appears that the database only has 26153 responses.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is from mining the genres from My anime list, there's a bunch of genre numbers that aren't being mapped to anything

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# NOT THE CAPTCHA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This kinda makes sense, as studios can be bought out

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The API is down :(

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Exponential Decay

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inconsistent Documentation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dude this api just annoys me now
#
# You need to IP swap in order for it to keep working
#
# BUT IM STILL USING THE SAME TOKEN?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# API doesn't respond

# %% [markdown]
# ![image.png](attachment:image.png)
# Romeo and Juliet

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# A 3 hour set back

# %% [markdown]
# ![image.png](attachment:image.png)
# Just trashed 2350 good rows of data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Maybe I should add MongoDB????

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# THE ZERO ERROR???????

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once again, ip switching solves this issue
